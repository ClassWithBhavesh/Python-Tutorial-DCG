# %%
# Merging | Concating | Joining DF's

# import pandas as pd

# li = [[1,2,3], [4,5,6], [7,8,9]]

# df = pd.DataFrame(li, columns=['a', 'b', 'c'], index=[10,20,30])
# df

# ds1 = pd.Series(data=['Z', 'X', 'Z', 'Y', 'Z', 'Y', 'Y'])
# ds2 = pd.Series(data=[10,20,30,40,50,60,70])
# ds1 = pd.Series(data=['Z', 'X', 'Z', 'Y'])
# ds2 = pd.Series(data=[10,20,30,40])

# df1 = pd.DataFrame({
#     'Name': ds1,
#     'Age': ds2
# })

# df2 = pd.DataFrame({
#     'Name': ds1,
#     'Id': [11,22,33,44, 55,66,77]
# })


# conDf = pd.concat([df1, df2])
# print(conDf)
# conDf1 = pd.concat([df1, df2], axis=0)
# print(conDf1)
# conDf2 = pd.concat([df1, df2], axis=1)
# print(conDf2)
# print(df1, df2)
# mergedDf = pd.merge(df1, df2, on='Name')
# mergedDf
# print(df1, df2)
# joinedDf = df1.join(df2.set_index('Name'), on='Name')
# len(joinedDf)
# joinedDf.count()
