# %% [markdown]
# # ***Histogram In Matplotlib***

# %%
import numpy as np

markArr = np.random.randint(0, 100, size=40)
markArr
# Out:
# array([24, 48, 74, 53, 25, 84, 48,  7, 36, 92, 73, 86, 16, 15, 73, 78, 77,
#         9, 13, 27, 79, 28,  3, 26, 11, 43,  6, 56, 80, 15, 66, 29, 49, 89,
#        12, 25, 68, 82, 86, 96])

# %%
import matplotlib.pyplot as plt


markListA = [68, 65, 94, 86, 42, 12, 74, 26, 67, 60, 39, 77, 54,  2, 79, 24, 83,
       30, 43, 15, 84, 73, 80, 56, 29, 32, 55, 66, 72, 63, 19, 98, 49, 46,
       85, 82, 87, 89,  6, 78]

markListB = [24, 48, 74, 53, 25, 84, 48,  7, 36, 92, 73, 86, 16, 15, 73, 78, 77,
        9, 13, 27, 79, 28,  3, 26, 11, 43,  6, 56, 80, 15, 66, 29, 49, 89,
       12, 25, 68, 82, 86, 96]

plt.hist(markListA, color='g', histtype='bar', edgecolor='yellow', orientation='horizontal', label="Students")
# plt.hist(markListA, color='g', histtype='stepfilled', edgecolor='yellow')
# plt.hist(markListA, color='g', bottom=1)
# plt.hist(markListA, bins=20, color='r', cumulative=-1)
# plt.hist(markListA, bins=20,range=(1, 200), color='b')
# plt.hist(markListB)
plt.title("Student's Marks Distribution Plot")
plt.legend()
plt.show()
